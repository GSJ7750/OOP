# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module5- Lab1

# %% [markdown]
# Start by importing whatever you need to import in order to make this lab work:

# %%
# .. your code here ..
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook

# %% [markdown]
# ### How to Get The Dataset

# %% [markdown]
# 1. Open up the City of Chicago's [Open Data | Crimes](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2) page.
# 1. In the `Primary Type` column, click on the `Menu` button next to the info button, and select `Filter This Column`. It might take a second for the filter option to show up, since it has to load the entire list first.
# 1. Scroll down to `GAMBLING`
# 1. Click the light blue `Export` button next to the `Filter` button, and select `Download As CSV`

# %% [markdown]
# Now that you have th dataset stored as a CSV, load it up being careful to double check headers, as per usual:

# %%
# .. your code here ..
df = pd.read_csv('Datasets/Crimes_-_2001_to_present.csv')

# %% [markdown]
# Get rid of any _rows_ that have nans in them:

# %%
# .. your code here ..
df = df.dropna()

# %% [markdown]
# Display the `dtypes` of your dset:

# %%
# .. your code here ..
df.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                      int64
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                    float64
# Community Area          float64
# FBI Code                  int64
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %% [markdown]
# Coerce the `Date` feature (which is currently a string object) into real date, and confirm by displaying the `dtypes` again. This might be a slow executing process...

# %%
# .. your code here ..
df.loc[:,'Date'] = df.loc[:,'Date'].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# IUCR                             int64
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                           float64
# Community Area                 float64
# FBI Code                         int64
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Updated On                      object
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %%
df1 = df.loc[:,(['Longitude', 'Latitude'])]
def doKMeans(df):
    # Let's plot your data with a '.' marker, a 0.3 alpha at the Longitude,
    # and Latitude locations in your dataset. Longitude = x, Latitude = y
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(df.Longitude, df.Latitude, marker='.', alpha=0.3, s = 30)

    
    # TODO: Filter `df` using indexing so it only contains Longitude and Latitude,
    # since the remaining columns aren't really applicable for this lab:
    #
    # .. your code here ..

    # TODO: Use K-Means to try and find seven cluster centers in this df.
    # Be sure to name your kmeans model `model` so that the printing works.
    #
    # .. your code here ..
    kmeans_model = KMeans(n_clusters = 7, init = 'random', n_init = 60, max_iter = 360, random_state = 43)
    #군집갯수, 초기화알고리즘, 중심초기화 횟수, kmeans 반복횟수, 난수생성(랜덤성부여)
    labels = kmeans_model.fit_predict(df)

    # Now we can print and plot the centroids:
    centroids = kmeans_model.cluster_centers_
    print(centroids)
    ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='red', alpha=0.5, linewidths=3, s=169)
    plt.show()

# %%
# Print & Plot your data
doKMeans(df1)
# Out:
# [[-87.75698307  41.89329421]
#  [-87.70972857  41.87814713]
#  [-87.61947863  41.80332831]
#  [-87.68540664  41.98128413]
#  [-87.5826157   41.75253468]
#  [-87.63103436  41.6966672 ]
#  [-87.66476188  41.77272033]]

# %% [markdown]
# Filter out the data so that it only contains samples that have a `Date > '2011-01-01'`, using indexing. Then, in a new figure, plot the crime incidents, as well as a new K-Means run's centroids.

# %%
# .. your code here ..
df2 = df1[df.Date > '2011-01-01']

# %%
# Print & Plot your data
doKMeans(df2)
plt.title("Dates limited to 2011 and later")
# Out:
# [[-87.6868321   41.98345852]
#  [-87.75484133  41.88994914]
#  [-87.58015258  41.75064571]
#  [-87.66518665  41.77546319]
#  [-87.71078387  41.87575213]
#  [-87.63400497  41.70549723]
#  [-87.61912036  41.79151425]]
# Text(0.5,1,'Dates limited to 2011 and later')

# %%
points = df1.values

# %%
kmeans = KMeans(n_clusters=7).fit(points)

# %%
kmeans.cluster_centers_
# Out:
# array([[-87.75689942,  41.89338841],
#        [-87.58243845,  41.75230925],
#        [-87.6850217 ,  41.98174333],
#        [-87.70972293,  41.87816429],
#        [-87.61939123,  41.80290526],
#        [-87.66487608,  41.77276958],
#        [-87.63110893,  41.69674023]])

# %%
kmeans.labels_
# Out:
# array([4, 5, 3, ..., 4, 5, 3])

# %%
df1['cluster'] = kmeans.labels_
df1.head()
# Out:
#    Longitude   Latitude  cluster
# 0 -87.613150  41.777826        4
# 1 -87.628342  41.764569        5
# 2 -87.723983  41.871646        3
# 3 -87.767904  41.893603        0
# 4 -87.722434  41.933674        0

# %%
import seaborn as sb

# %%
sb.lmplot('Longitude', 'Latitude', data=df1, fit_reg=False, scatter_kws={"s": 50}, hue="cluster", markers='.')

plt.title('K-means Example')
# Out:
# <img src="data:image/png;base64,..." width="707">
# Text(0.5,1,'K-means Example')

# %%
doKMeans(df1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[-8.77097229e+01  4.18781643e+01  3.00000000e+00]
#  [-8.76310728e+01  4.16967032e+01  6.00000000e+00]
#  [-8.75825161e+01  4.17524301e+01  1.00000000e+00]
#  [-8.76850217e+01  4.19817433e+01  2.00000000e+00]
#  [-8.77568994e+01  4.18933884e+01 -1.51878510e-13]
#  [-8.76194184e+01  4.18032170e+01  4.00000000e+00]
#  [-8.76647621e+01  4.17727358e+01  5.00000000e+00]]
